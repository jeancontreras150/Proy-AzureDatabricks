# %%
dbutils.widgets.removeAll()

# %%
## PARAMETRIZAR ADLS Y CATALOGO A PROD
dbutils.widgets.text("PRM_catalogo","catalogo_desa_intEcommerce")
dbutils.widgets.text("storageName","adlsecompag")
dbutils.widgets.text("ambiente","desa")

PRM_catalogo = dbutils.widgets.get("PRM_catalogo")
storageName = dbutils.widgets.get("storageName")
ambiente = dbutils.widgets.get("ambiente")

# %%
spark.sql(f"use catalog {PRM_catalogo}")

# %%
#CREANDO GRUPOS
spark.sql(f"CREATE GROUP `Data_Engineers`;")
spark.sql(f"CREATE GROUP `Data_Custodians`;")
spark.sql(f"CREATE GROUP `Data_Stewards`;")
spark.sql(f"CREATE GROUP `Product_Owners`;")
spark.sql(f"CREATE GROUP `Data_Analysts`;")

# %%
spark.sql(f"""ALTER GROUP `Data_Engineers`
ADD USER `dataengineer01ac@jeancontreras150outlook.onmicrosoft.com`;
""")
spark.sql(f"""ALTER GROUP `Data_Engineers`
ADD USER `dataengineer02ac@jeancontreras150outlook.onmicrosoft.com`;
""")


spark.sql(f"""ALTER GROUP `Data_Stewards`
ADD USER `datasteward01fd@jeancontreras150outlook.onmicrosoft.com`;
""")


spark.sql(f"""ALTER GROUP `Product_Owners`
ADD USER `productowner01gt@jeancontreras150outlook.onmicrosoft.com`;
""")

spark.sql(f"""ALTER GROUP `Data_Analysts`
ADD USER `productowner02df@jeancontreras150outlook.onmicrosoft.com`;
""")

# %%
##GRANT A LOS ESQUEMAS VISTA BRONCE
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data TO `Data_Analysts`;""")

# %%
##GRANT SELECT A LA VISTA DATOS CRITICOS
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_vdc.Clientes_Sistema TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_vdc.Clientes_Sistema TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.bronze_vdc.Clientes_Sistema TO `Data_Analysts`;""")

# %%
##GRANT A LOS ESQUEMAS VISTA SILVER
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce TO `Data_Analysts`;""")

# %%
##GRANT SELECT A LA VISTA DATOS CRITICOS
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_vdc.Tabla_Cliente TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_vdc.Tabla_Cliente TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.silver_vdc.Tabla_Cliente TO `Data_Analysts`;""")

# %%
##GRANT A LOS ESQUEMAS VISTA SILVER
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras TO `Data_Engineers`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras TO `Data_Custodians`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras TO `Data_Analysts`;""")

# %%
##GRANT SELECT A LA VISTA DATOS CRITICOS
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_vdc.Interaccion_Analisis TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_vdc.Interaccion_Analisis TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_vdc.Interaccion_Analisis TO `Data_Analysts`;""")

spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_vdc.Clientes_Top_Compras TO `Data_Stewards`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_vdc.Clientes_Top_Compras TO `Product_Owners`;""")
spark.sql(f"""GRANT SELECT ON TABLE {PRM_catalogo}.golden_vdc.Clientes_Top_Compras TO `Data_Analysts`;""")

# %%
##GRANT A LEER ARCHIVOS EN CONTAINER PROD
spark.sql(f"""GRANT READ FILES
ON EXTERNAL LOCATION `exlt-raw-insumos-{ambiente}`
TO `Data_Engineers`;
""")

spark.sql(f"""GRANT READ FILES
ON EXTERNAL LOCATION `exlt-cont-ecom-{ambiente}`
TO `Data_Engineers`;
""")
##
