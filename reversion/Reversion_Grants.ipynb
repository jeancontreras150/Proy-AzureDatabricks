# %%
dbutils.widgets.removeAll()

# %%
## PARAMETRIZAR ADLS Y CATALOGO A PROD
dbutils.widgets.text("PRM_catalogo","catalogo_desa_intEcommerce")
dbutils.widgets.text("storageName","adlsecompag")
dbutils.widgets.text("ambiente","desa")

PRM_catalogo = dbutils.widgets.get("PRM_catalogo")
storageName = dbutils.widgets.get("storageName")
ambiente = dbutils.widgets.get("ambiente")

# %%
spark.sql(f"use catalog {PRM_catalogo}")

# %%
# REVOKE SELECT A LOS ESQUEMAS VISTA BRONCE

# Clientes_Sistema
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Clientes_Sistema FROM `Data_Analysts`;""")

# Productos_Sistema
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Productos_Sistema FROM `Data_Analysts`;""")

# Interaccion_Sistema
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.Interaccion_Sistema FROM `Data_Analysts`;""")

# ecommerce_data
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_v.ecommerce_data FROM `Data_Analysts`;""")


## REVOKE SELECT A LA VISTA DATOS CRITICOS - BRONZE
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_vdc.Clientes_Sistema FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_vdc.Clientes_Sistema FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.bronze_vdc.Clientes_Sistema FROM `Data_Analysts`;""")


## REVOKE SELECT A LOS ESQUEMAS VISTA SILVER

# Tabla_Cliente
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Cliente FROM `Data_Analysts`;""")

# Tabla_Destipinteraccion
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Destipinteraccion FROM `Data_Analysts`;""")

# Tabla_Producto
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_Producto FROM `Data_Analysts`;""")

# Tabla_IntEcommerce
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_v.Tabla_IntEcommerce FROM `Data_Analysts`;""")



## REVOKE SELECT A LA VISTA DATOS CRITICOS
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_vdc.Tabla_Cliente FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_vdc.Tabla_Cliente FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.silver_vdc.Tabla_Cliente FROM `Data_Analysts`;""")



## REVOKE SELECT A LOS ESQUEMAS VISTA SILVER

# Tabla: Interaccion_Analisis
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Interaccion_Analisis FROM `Data_Analysts`;""")

# Tabla: Categoria_Top_Ecommerce
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Categoria_Top_Ecommerce FROM `Data_Analysts`;""")

# Tabla: Clientes_Top_Compras
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras FROM `Data_Engineers`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras FROM `Data_Custodians`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_v.Clientes_Top_Compras FROM `Data_Analysts`;""")


## REVOKE SELECT A LA VISTA DATOS CRITICOS
# Tabla: Interaccion_Analisis
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_vdc.Interaccion_Analisis FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_vdc.Interaccion_Analisis FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_vdc.Interaccion_Analisis FROM `Data_Analysts`;""")

# Tabla: Clientes_Top_Compras
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_vdc.Clientes_Top_Compras FROM `Data_Stewards`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_vdc.Clientes_Top_Compras FROM `Product_Owners`;""")
spark.sql(f"""REVOKE SELECT ON TABLE {PRM_catalogo}.golden_vdc.Clientes_Top_Compras FROM `Data_Analysts`;""")



spark.sql(f"""REVOKE READ FILES
ON EXTERNAL LOCATION `exlt-raw-insumos-{ambiente}`
FROM `Data_Engineers`;
""")

spark.sql(f"""REVOKE READ FILES
ON EXTERNAL LOCATION `exlt-cont-ecom-{ambiente}`
FROM `Data_Engineers`;
""")


## REVERSION: REMOVER USUARIOS DE LOS GRUPOS

# Grupo: Data_Engineers
spark.sql(f"""ALTER GROUP `Data_Engineers`
DROP USER `dataengineer01ac@jeancontreras150outlook.onmicrosoft.com`;
""")
spark.sql(f"""ALTER GROUP `Data_Engineers`
DROP USER `dataengineer02ac@jeancontreras150outlook.onmicrosoft.com`;
""")

# Grupo: Data_Stewards
spark.sql(f"""ALTER GROUP `Data_Stewards`
DROP USER `datasteward01fd@jeancontreras150outlook.onmicrosoft.com`;
""")

# Grupo: Product_Owners
spark.sql(f"""ALTER GROUP `Product_Owners`
DROP USER `productowner01gt@jeancontreras150outlook.onmicrosoft.com`;
""")

# Grupo: Data_Analysts
spark.sql(f"""ALTER GROUP `Data_Analysts`
DROP USER `productowner02df@jeancontreras150outlook.onmicrosoft.com`;
""")

#BORRAR LOS GRUPOS DE USUARIOS POR MEDIO DE LA INTERFAZ DE DB
